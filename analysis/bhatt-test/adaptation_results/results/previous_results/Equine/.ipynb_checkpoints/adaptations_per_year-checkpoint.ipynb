# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import pylab
import numpy as np

# %%
with open("./h3nx_ha_3_3_adaptation_bootstrapped.json","r") as file:
    jsonData = json.load(file)

#print(jsonData)

# fig = px.scatter(df, x='window_midpoint', y='adaptive_substitutions_per_codon', title='Scatter Plot')
# fig.show()

x = jsonData['window_midpoint']
y = jsonData['adaptive_substitutions_per_codon']

a, b = np.polyfit(x, y, 1)

plt.scatter(x,y)

plt.plot(x, a*x+b)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 16
#      12 a, b = np.polyfit(x, y, 1)
#      14 plt.scatter(x,y)
# ---> 16 plt.plot(x, a*x+b)
#      18 plt.show()
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'
