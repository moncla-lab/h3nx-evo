# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import numpy as np
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import os
import math

# %%
#where all the host folders and the jsons live
main_folder = './results'
host_folders = [folder for folder in os.listdir(main_folder) if os.path.isdir(os.path.join(main_folder, folder))]

#what we are plotting
all_genes = []
all_hosts = []
all_slopes = [] #rate of adaptation
all_lower_95cis = []
all_upper_95cis = []

for host_folder in host_folders:
    host_path = os.path.join(main_folder, host_folder)
    json_files = [file for file in os.listdir(host_path) if file.endswith('.json')]
    for json_file in json_files:
        json_path = os.path.join(host_path, json_file)

        with open(json_path, 'r') as file:
            data = json.load(file)

        rate_of_adaptation = data["rate_of_adaptation"]
        bootstrap_rate_of_adaptation = data["bootstrap_rate_of_adaptation"]

        slope_sci = rate_of_adaptation * (10**3)
        bs_slope_sci = [x * (10**3) for x in bootstrap_rate_of_adaptation]
        lower_95ci = np.percentile(sorted(bs_slope_sci), 2.5)
        upper_95ci = np.percentile(sorted(bs_slope_sci), 97.5)

        all_genes.append(data['gene'].upper()) 
        all_hosts.append(data['host'].replace(' ', '\n')) 
        all_slopes.append(slope_sci)
        all_lower_95cis.append(lower_95ci)
        all_upper_95cis.append(upper_95ci)


#transforming data into df
all_data = {
    'gene': all_genes,
    'host': all_hosts,
    'adaptive_subs_per_codon_per_year': all_slopes,
    'lower_95ci': all_lower_95cis,
    'upper_95ci': all_upper_95cis,
    'ci': list(zip(all_lower_95cis, all_upper_95cis)),
}

df_all = pd.DataFrame(all_data)

# %%
color_and_host_order_map = {
    'Eurasian\nAvian': 'red',
    'NA\nAvian': 'lightcoral',
    'swineEuro': 'blue',
    'swineNA': 'blueviolet',
    'canineH3N2': 'saddlebrown',
    'canineH3N8': 'chocolate',
    'equine': 'pink',
    'human': 'darkturquoise'
}

genes = list(map(str.upper, ['HA', 'NA', 'PB1', 'PB2', 'PA', "NP"]))
hosts = list(map(str.upper, [
    'Eurasian\nAvian',
    'NA\nAvian',
    'swineEuro',
    'swineNA',
    'canineH3N2',
    'canineH3N8',
    'equine',
    'human'
]))

df_to_use = df_all.copy()
df_to_use['color'] = df_to_use['host'].map(color_and_host_order_map)

number_of_cols = 3
number_of_plots = len(genes)
number_of_rows = math.ceil(number_of_plots/number_of_cols)

fig = make_subplots(
    subplot_titles=genes,
    rows=number_of_rows, 
    cols=number_of_cols,
    shared_yaxes='all',
    vertical_spacing=0.25,
    horizontal_spacing = 0.05
)

for idx, gene in enumerate(genes):
    subset_df = df_to_use[df_to_use["gene"] == gene]
    
    
    row_idx = idx // number_of_cols + 1
    column_idx = idx % number_of_cols + 1
    
    print(gene, row_idx, column_idx)
    
    for host in hosts:
    
        
        sub_subset_df = subset_df[subset_df["host"].str.upper() == host]
        
        if sub_subset_df.empty:
            # raise RuntimeError(f"Host: {host} was not present in gene: {gene}")
            continue
        
        fig.add_trace(
            go.Scatter(
                x=sub_subset_df["host"], 
                y=sub_subset_df["adaptive_subs_per_codon_per_year"],
                name=host,
                text=gene,
                marker=dict(
                    color=sub_subset_df["color"].values[0],
                    size=10
                ),
                mode = "markers",
                error_y=dict(
                    type = 'data',
                    array = sub_subset_df["upper_95ci"] - sub_subset_df["adaptive_subs_per_codon_per_year"],
                    arrayminus = sub_subset_df["adaptive_subs_per_codon_per_year"] - sub_subset_df["lower_95ci"],
                    visible = True,
                    color = sub_subset_df["color"].values[0],
                    width=0,
                    thickness=3
                ),
                legendgroup=host,
                showlegend= idx == 1
            ),
            #where it adds data
            row = row_idx, 
            col = column_idx
        )
        
    #this makes the tick labels show for all plots
    getattr(fig.layout, 'yaxis' if idx == 0 else f'yaxis{idx}').showticklabels = True


    #this makes the title appear next to each row
    # if row_idx == 1:
    #     getattr(fig.layout, 'yaxis' if idx == 0 else f'yaxis{idx}').title = r'Adaptive Muts per Codon<br>per Year (x10^-3)'
        
fig.update_annotations(font_size=25)
            
fig.update_layout(
    font_size=18,
    width=1600,
    height=1000
)
fig.update_xaxes(tickangle=-55, tickfont_size=20)
fig.update_yaxes(tickfont_size=20)
fig.add_hline(y=1.17, line_width=1, line_dash="dash", line_color="black")
    
fig.show()
# Out:
# HA 0 1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[57], line 58
#      54     if sub_subset_df.empty:
#      55         # raise RuntimeError(f"Host: {host} was not present in gene: {gene}")
#      56         continue
# ---> 58     fig.add_trace(
#      59         go.Scatter(
#      60             x=sub_subset_df["host"],
#      61             y=sub_subset_df["adaptive_subs_per_codon_per_year"],
#      62             name=host,
#      63             text=gene,
#      64             marker=dict(
#      65                 color=sub_subset_df["color"].values[0],
#      66                 size=10
#      67             ),
#      68             mode = "markers",
#      69             error_y=dict(
#      70                 type = 'data',
#      71                 array = sub_subset_df["upper_95ci"] - sub_subset_df["adaptive_subs_per_codon_per_year"],
#      72                 arrayminus = sub_subset_df["adaptive_subs_per_codon_per_year"] - sub_subset_df["lower_95ci"],
#      73                 visible = True,
#      74                 color = sub_subset_df["color"].values[0],
#      75                 width=0,
#      76                 thickness=3
#      77             ),
#      78             legendgroup=host,
#      79             showlegend= idx == 1
#      80         ),
#      81         #where it adds data
#      82         row = row_idx,
#      83         col = column_idx
#      84     )
#      86 #this makes the tick labels show for all plots
#      87 getattr(fig.layout, 'yaxis' if idx == 0 else f'yaxis{idx}').showticklabels = True
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:865, in Figure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#     790 def add_trace(
#     791     self, trace, row=None, col=None, secondary_y=None, exclude_empty_subplots=False
#     792 ) -> "Figure":
#     793     """
#     794
#     795     Add a trace to the figure
#    (...)
#     863
#     864     """
# --> 865     return super(Figure, self).add_trace(
#     866         trace, row, col, secondary_y, exclude_empty_subplots
#     867     )
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:2097, in BaseFigure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#    2088         self.add_trace(
#    2089             trace,
#    2090             row=r,
#    (...)
#    2093             exclude_empty_subplots=exclude_empty_subplots,
#    2094         )
#    2095     return self
# -> 2097 return self.add_traces(
#    2098     data=[trace],
#    2099     rows=[row] if row is not None else None,
#    2100     cols=[col] if col is not None else None,
#    2101     secondary_ys=[secondary_y] if secondary_y is not None else None,
#    2102     exclude_empty_subplots=exclude_empty_subplots,
#    2103 )
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:945, in Figure.add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#     869 def add_traces(
#     870     self,
#     871     data,
#    (...)
#     875     exclude_empty_subplots=False,
#     876 ) -> "Figure":
#     877     """
#     878
#     879     Add traces to the figure
#    (...)
#     943
#     944     """
# --> 945     return super(Figure, self).add_traces(
#     946         data, rows, cols, secondary_ys, exclude_empty_subplots
#     947     )
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:2227, in BaseFigure.add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#    2225 if rows is not None:
#    2226     for trace, row, col, secondary_y in zip(data, rows, cols, secondary_ys):
# -> 2227         self._set_trace_grid_position(trace, row, col, secondary_y)
#    2229 if exclude_empty_subplots:
#    2230     data = list(
#    2231         filter(
#    2232             lambda trace: self._subplot_not_empty(
#    (...)
#    2236         )
#    2237     )
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:2319, in BaseFigure._set_trace_grid_position(self, trace, row, col, secondary_y)
#    2316 from plotly._subplots import _set_trace_grid_reference
#    2318 grid_ref = self._validate_get_grid_ref()
# -> 2319 return _set_trace_grid_reference(
#    2320     trace, self.layout, grid_ref, row, col, secondary_y
#    2321 )
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/_subplots.py:1344, in _set_trace_grid_reference(trace, layout, grid_ref, row, col, secondary_y)
#    1341 def _set_trace_grid_reference(trace, layout, grid_ref, row, col, secondary_y=False):
#    1343     if row <= 0:
# -> 1344         raise Exception(
#    1345             "Row value is out of range. " "Note: the starting cell is (1, 1)"
#    1346         )
#    1347     if col <= 0:
#    1348         raise Exception(
#    1349             "Col value is out of range. " "Note: the starting cell is (1, 1)"
#    1350         )
#
# Exception: Row value is out of range. Note: the starting cell is (1, 1)

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


main_folder = './results'
host_folders = [folder for folder in os.listdir(main_folder) if os.path.isdir(os.path.join(main_folder, folder))]


all_genes = []
all_hosts = []
all_slopes = []
all_lower_95cis = []
all_upper_95cis = []


for host_folder in host_folders:
    host_path = os.path.join(main_folder, host_folder)


    json_files = [file for file in os.listdir(host_path) if file.endswith('.json')]


    for json_file in json_files:
        json_path = os.path.join(host_path, json_file)


        with open(json_path, 'r') as file:
            data = json.load(file)


        rate_of_adaptation = data["rate_of_adaptation"]
        bootstrap_rate_of_adaptation = data["bootstrap_rate_of_adaptation"]

        slope_sci = rate_of_adaptation * (10**3)
        bs_slope_sci = [x * (10**3) for x in bootstrap_rate_of_adaptation]
        lower_95ci = np.percentile(sorted(bs_slope_sci), 2.5)
        upper_95ci = np.percentile(sorted(bs_slope_sci), 97.5)


        all_genes.append(data['gene'].upper()) 
        all_hosts.append(data['host'].replace(' ', '\n'))
        all_slopes.append(slope_sci)
        all_lower_95cis.append(lower_95ci)
        all_upper_95cis.append(upper_95ci)


all_data = {
    'gene': all_genes,
    'host': all_hosts,
    'adaptive_subs_per_codon_per_year': all_slopes,
    'lower_95ci': all_lower_95cis,
    'upper_95ci': all_upper_95cis,
    'ci': list(zip(all_lower_95cis, all_upper_95cis)),
}

df_all = pd.DataFrame(all_data)

for gene, group_df in df_all.groupby('gene'):
    fig, axs = plt.subplots(sharey=True)
    axs.errorbar(group_df['host'], group_df['adaptive_subs_per_codon_per_year'],
                yerr=[group_df['adaptive_subs_per_codon_per_year'] - group_df['lower_95ci'], group_df['upper_95ci'] - group_df['adaptive_subs_per_codon_per_year']],
                fmt='o')

    axs.set_ylabel(r'Adaptive Muts per Codon per Year $(x 10^{-3})$')
    axs.set_title(gene)
    axs.set_xticks(range(len(group_df['host'])))
    axs.set_xticklabels(group_df['host'], rotation=45, ha='right')
    plt.show()
