# %%
import baltic as bt
import pandas as pd
import json
import os

# %% [markdown]
# # Last updated the host-specific fasta files on 1/22/2024

# %%
def load_tree(gene):
    tree_path = f"/Users/monclalab1/Documents/nonhuman_H3_project/non-human-h3/auspice/h3nx_{gene}.json"
    mytree, mymeta = bt.loadJSON(tree_path)
    return(mytree)

# %%
#for practice
count = 0
for k in mytree.Objects:
    if k.branchType == "node": #can also be =="leaf"
        count+=1
        if count <1000:
            pass
            # for i in k.children:
            #     if i.branchType == "leaf":
            #         print(i.traits)

# %% [markdown]
# # HA Clades

# %%
#HA swine/human host clades

mytree = load_tree("ha")

cladeHuman = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003668': #1965
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003836': #1976
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])


cladeSwineThailand = [] #only 166 isolates here
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004381': #1994
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])
            
cladeNA1995 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004554':
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America":
                    cladeNA1995.append(i.traits["name"])

cladeNA2012 = [] #only 192 isolates here
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0006050':
            cladeNA2 = mytree.subtree(k = k)
            for i in cladeNA2.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America":
                    cladeNA2012.append(i.traits["name"])
                    
cladeChinaViet = [] #china, hong kong, vietnam
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0005554': #2007
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
                    cladeChinaViet.append(i.traits["name"])

# %%
#HA nonswine clades

cladeH3N2canine = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003257': #2005
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])

cladeH3N8canine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001578': #2002
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001264': #1955
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])

#avian clades

cladeNA_Avian = [] #could argue there are 2 independent clades that were introduced at the same time
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000578': #1946
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian.append(i.traits["name"])
                

cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001997': #1977
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1995Swine" : cladeNA1995,
    "NA2012Swine" : cladeNA2012,
    "thaiSwine" : cladeSwineThailand,
    "chinaVietSwine" : cladeChinaViet,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # NA Clades

# %%
#NA swine/human host clades
mytree = load_tree("na")

cladeHuman = [] # 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004655': #1969
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002593': #1980
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])


cladeSwineThailand = [] #only 166 isolates here
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004174': #1993
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])

            
cladeNA2000 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004986': #2001
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA2000.append(i.traits["name"])

                    
cladeChinaViet = [] #china, hong kong, vietnam
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004681': #2003
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
                    cladeChinaViet.append(i.traits["name"])

# %%
#NA nonswine clades

cladeH3N2canine = [] #325 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003720': #2005
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine" and i.traits["subtype"] == "H3N2": 
                cladeH3N2canine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

cladeH3N8canine = [] #only 58 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001253': #2003
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine" and i.traits["subtype"] == "H3N8": 
                cladeH3N8canine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001000': #1954
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine" and i.traits["subtype"] == "H3N8": 
                cladeEquine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

#avian clades

cladeNA_Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000986': #1955
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian.append(i.traits["name"])
                

cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001552': #1948
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA2000Swine" : cladeNA2000,
    "thaiSwine" : cladeSwineThailand,
    "chinaVietSwine" : cladeChinaViet,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # PB1 Clades

# %%
#PB1 swine/human host clades

mytree = load_tree("pb1")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001387': #1967
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])
                
cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003570': #1976
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])

cladeSwineThailand = [] #only 147 isolates here
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0001928': #2006
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])

            
cladeNA2000 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0002483': 
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA2000.append(i.traits["name"])

                    
cladeChinaViet = [] #only 89 here
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0002061': #2006
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
                    cladeChinaViet.append(i.traits["name"])
# Out:
# Tree height: 118.587713
# Tree length: 13197.822877
# annotations present
#
# Numbers of objects in tree: 9418 (4214 nodes and 5204 leaves)

# %%
#PB1 nonswine clades

cladeH3N2canine = [] #328 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004327': #2004
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])


cladeH3N8canine = [] #only 44 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003403': #2002
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003253': #1955
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])

#avian clades

cladeNA_Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001363': #1964
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian.append(i.traits["name"])
                

cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003979': #1973
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA2000Swine" : cladeNA2000,
    "thaiSwine" : cladeSwineThailand,
    "chinaVietSwine" : cladeChinaViet,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # PA Clades

# %%
#PA swine/human host clades

mytree = load_tree("pa")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004894': #1948
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003588': #1975
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])
                leaf_list.append(i.traits["name"])


cladeSwineThailand = [] #129 samples
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0005462': #2007
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])
                    leaf_list.append(i.traits["name"])
            
cladeNA1995 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0000307': #1997
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA1995.append(i.traits["name"])
                    leaf_list.append(i.traits["name"])
                    
cladeChinaViet = [] 
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0005431': #2007
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
                    cladeChinaViet.append(i.traits["name"])
                    leaf_list.append(i.traits["name"])
# Out:
# Tree height: 109.361975
# Tree length: 12855.932551
# annotations present
#
# Numbers of objects in tree: 9446 (4220 nodes and 5226 leaves)

# %%
#PA nonswine clades

cladeH3N2canine = [] #328 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001807': #2005
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

cladeH3N8canine = [] #only 44 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004708': #2002
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004563': #1956
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])
                leaf_list.append(i.traits["name"])

#avian clades

cladeNA_Avian_1969 = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002606': #north american avian
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian_1969.append(i.traits["name"])
                

cladeNA_Avian_1952 = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004003': #north american avian
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian_1952.append(i.traits["name"])
                
cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002618': #1959
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1995Swine" : cladeNA1995,
    "thaiSwine" : cladeSwineThailand,
    "chinaVietSwine" : cladeChinaViet,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NA1952Avian" : cladeNA_Avian_1952,
    "NA1969Avian" : cladeNA_Avian_1969
}

# %% [markdown]
# # NP Clades

# %%
mytree = load_tree("np")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003472': #1965
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001544': #1972
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])


# cladeSwineThailand = [] #only 72 isolates here, 2014, theres another clade with ~50 from 2007 that i did NOT include
# for k in mytree.Objects:
#         if k.branchType == "node" and k.traits['name'] == 'NODE_0004573':
#             cladeThai = mytree.subtree(k = k)
#             for i in cladeThai.Objects:
#                 if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
#                     cladeSwineThailand.append(i.traits["name"])
            
cladeNA1995 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0003956':
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA1995.append(i.traits["name"])
                    
cladeChinaViet = [] 
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004613': #2002
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
                    cladeChinaViet.append(i.traits["name"])
# Out:
# Tree height: 88.474034
# Tree length: 20212.479305
# annotations present
#
# Numbers of objects in tree: 9741 (4372 nodes and 5369 leaves)

# %%
#NP nonswine clades

cladeH3N2canine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002200': #2001
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])

cladeH3N8canine = [] #only 63 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000239': #1998
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003444': #1940
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine" and i.traits["name"] != "A/equine/Jilin/1/1989": 
                cladeEquine.append(i.traits["name"])

#avian clades

cladeNA_Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001318': #1962
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America":
                cladeNA_Avian.append(i.traits["name"])
                
cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001330': #1962
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1995Swine" : cladeNA1995,
    "chinaVietSwine" : cladeChinaViet,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # PB2 Clades

# %%
#pb2 swine/human host clades

mytree = load_tree("pb2")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003176': #1944
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])
                

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004249': #1975
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])
                


cladeSwineThailand = [] #134 sequences
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0001804': #2008
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])
                    
            
cladeNA2000 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0001958':
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA2000.append(i.traits["name"])
                    
                    
# cladeChinaViet = [] #no clear clade
# for k in mytree.Objects:
#         if k.branchType == "node" and k.traits['name'] == 'NODE_0005255':
#             cladeChi = mytree.subtree(k = k)
#             for i in cladeChi.Objects:
#                 if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
#                     cladeChinaViet.append(i.traits["name"])
#                     leaf_list.append(i.traits["name"])
# Out:
# Tree height: 111.797955
# Tree length: 13119.743115
# annotations present
#
# Numbers of objects in tree: 9401 (4197 nodes and 5204 leaves)

# %%
#pb2 nonswine clades

cladeH3N2canine = [] #342 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0004879': #2005
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])
                

cladeH3N8canine = [] #only 45 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003019': #2002
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])
                

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002871': #1958
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])
                

#avian clades

cladeNA_Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002863': #1947
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian.append(i.traits["name"])

                
cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003536': #1947
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA2000Swine" : cladeNA2000,
    "thaiSwine" : cladeSwineThailand,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # MP Clades

# %%
mytree = load_tree("mp")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001381': #1961
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003935': #1985
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])


cladeSwineThailand = [] #126 sequences
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0005089': #2006
            cladeThai = mytree.subtree(k = k)
            for i in cladeThai.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
                    cladeSwineThailand.append(i.traits["name"])
            
cladeNA1986 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0001747': #equivalent to 1995 for HA?
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": 
                    cladeNA1986.append(i.traits["name"])


cladeNA2005 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004320': #equivalent to 2000?
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": #USA/CAN 1999 equivalent
                    cladeNA2005.append(i.traits["name"])
                    
cladeChinaViet = [] #only 94 sequences
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004717': #2008
            cladeChi = mytree.subtree(k = k)
            for i in cladeChi.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): 
                    cladeChinaViet.append(i.traits["name"])
# Out:
# Tree height: 111.982247
# Tree length: 17293.149893
# annotations present
#
# Numbers of objects in tree: 9629 (4137 nodes and 5492 leaves)

# %%
#mp nonswine clades

cladeH3N2canine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003538': #2003
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])

cladeH3N8canine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002294': #2001
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])

cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002116': #1959
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])

#avian clades

cladeNA_Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000449': #1947, equivalent to HA
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA_Avian.append(i.traits["name"])
                
cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002693': #1960
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1986Swine" : cladeNA1986,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NAAvian" : cladeNA_Avian
}

# %% [markdown]
# # NS Clades

# %%
#ns swine/human host clades
mytree = load_tree("ns")

cladeHuman = [] #only human
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0003524': #human
        cladeHum = mytree.subtree(k = k)
        for i in cladeHum.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Human": 
                cladeHuman.append(i.traits["name"])

cladeSwineEuro = []
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001877': #europe
        cladeEuro = mytree.subtree(k = k)
        for i in cladeEuro.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "Europe": 
                cladeSwineEuro.append(i.traits["name"])


# cladeSwineThailand = [] #70 sequences, not worth it because it is only 3 years
# for k in mytree.Objects:
#         if k.branchType == "node" and k.traits['name'] == 'NODE_0002409':
#             cladeThai = mytree.subtree(k = k)
#             for i in cladeThai.Objects:
#                 if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["country"] == "Thailand": #thai
#                     cladeSwineThailand.append(i.traits["name"])

            
cladeNA1968 = [] #usa,can,mexico
for k in mytree.Objects:
        if k.branchType == "node" and k.traits['name'] == 'NODE_0004179':
            cladeNA1 = mytree.subtree(k = k)
            for i in cladeNA1.Objects:
                if i.branchType == "leaf" and i.traits["host"] == "Swine" and i.traits["region"] == "North America": 
                    cladeNA1968.append(i.traits["name"])


                    
# cladeChinaViet = [] #only 55 sequences
# for k in mytree.Objects:
#         if k.branchType == "node" and k.traits['name'] == '':
#             cladeChi = mytree.subtree(k = k)
#             for i in cladeChi.Objects:
#                 if i.branchType == "leaf" and i.traits["host"] == "Swine" and (i.traits["region"] == "China" or i.traits["country"] == "Vietnam"): #USA/CAN 1999 equivalent
#                     cladeChinaViet.append(i.traits["name"])
# Out:
# Tree height: 318.426325
# Tree length: 39427.004807
# annotations present
#
# Numbers of objects in tree: 9528 (4100 nodes and 5428 leaves)

# %%
#ns nonswine clades updated 1/22/2024

cladeH3N2canine = [] #341 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0001401': #H3N2 canine
        cladeN2dog = mytree.subtree(k = k)
        for i in cladeN2dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N2canine.append(i.traits["name"])


cladeH3N8canine = [] #only 99 isolates
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002402': #H3N8 canine
        cladeN8dog = mytree.subtree(k = k)
        for i in cladeN8dog.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Canine": 
                cladeH3N8canine.append(i.traits["name"])


cladeEquine = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002312': #H3N8 equine
        cladeHorse = mytree.subtree(k = k)
        for i in cladeHorse.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Equine": 
                cladeEquine.append(i.traits["name"])


#avian clades updated 1/22/2024

cladeNA1946Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000503': #north american avian
        cladeNA1946 = mytree.subtree(k = k)
        for i in cladeNA1946.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA1946Avian.append(i.traits["name"])
                
cladeNA1949Avian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0002707': #north american avian
        cladeNAbird = mytree.subtree(k = k)
        for i in cladeNAbird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and i.traits["region"] == "North America": 
                cladeNA1949Avian.append(i.traits["name"])

cladeEurasiaAvian = [] 
for k in mytree.Objects:
    if k.branchType == "node" and k.traits['name'] == 'NODE_0000779': 
        cladeEurasiabird = mytree.subtree(k = k)
        for i in cladeEurasiabird.Objects:
            if i.branchType == "leaf" and i.traits["host"] == "Avian" and (i.traits["region"] != "North America" or i.traits["region"] != "Africa" or i.traits["region"] != "Oceania"): 
                cladeEurasiaAvian.append(i.traits["name"])

# %%
h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1968Swine" : cladeNA1968,
    "canineH3N2" : cladeH3N2canine
}

h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NA1949Avian" : cladeNA1949Avian,
    "NA1946Avian" : cladeNA1946Avian
}

# %% [markdown]
# # Subsetting code

# %%
#this converts fasta files into dataframes

def fasta_to_df(fasta_file):
    
    fasta_data = []
    
    with open(fasta_file) as f:
        header = ""
        sequence = ""
        for line in f:
            if line.startswith(">"):
                if header != "":
                    fasta_data.append({"header": header, "sequence": sequence})
                header = line.strip() 
                sequence = ""
            else:
                sequence += line.strip()
        fasta_data.append({"header": header, "sequence": sequence}) #last line
            
    return pd.DataFrame(fasta_data)

# %%
def fasta_writer(path, filename, df):
            
    try:  
        os.mkdir(path)

    except OSError as error:
        pass

    with open(f"{path}{filename}", "w") as f:
        for index, row in df.iterrows():
            f.write(f"{row['header']}\n")
            f.write(f"{row['sequence']}\n")

# %%
def host_subsetting(gene, h3n2_list, h3n8_list):

    #subsetting the existing fasta file to only have the strains from the specific subtype
    df = fasta_to_df(f"/Users/monclalab1/Documents/nonhuman_H3_project/non-human-h3/sequences/h3nx_{gene}.fasta")
    
    df['Strain'] = df['header'].str.split("|").str[0]
    df['Strain'] = df['Strain'].str[1:]

    for key, value in h3n2_list.items():
        subset_df = df[df["Strain"].isin(value)]
        
        fasta_writer(f"/Users/monclalab1/Documents/nonhuman_H3_project/non-human-h3/analysis/host_specific/04-2023_11-2023/sep_by_clade/h3n2/{key}/", f"h3nx_{gene}.fasta", subset_df)

    for key, value in h3n8_list.items():
        subset_df = df[df["Strain"].isin(value)]

        fasta_writer(f"/Users/monclalab1/Documents/nonhuman_H3_project/non-human-h3/analysis/host_specific/04-2023_11-2023/sep_by_clade/h3n8/{key}/", f"h3nx_{gene}.fasta", subset_df)

# %%
host_subsetting("ns", h3n2, h3n8)

# %%
master_h3n2 = {
    "human" : cladeHuman, 
    "euroSwine" : cladeSwineEuro,
    "NA1968Swine" : cladeNA1968,
    "canineH3N2" : cladeH3N2canine,
    "NA1995Swine" : cladeNA1995,
    "NA2012Swine" : cladeNA2012,
    "thaiSwine" : cladeSwineThailand,
    "chinaVietSwine" : cladeChinaViet
    
}

master_h3n8 = {
    "canineH3N8" : cladeH3N8canine,
    "equine" : cladeEquine,
    "eurasianAvian" : cladeEurasiaAvian,
    "NA1946Avian": cladeNA1946Avian,
    "NA1949Avian": cladeNA1949Avian,
    "NAAvian" : cladeNA_Avian
}
